# %%
# ダウンロードする
import urllib.request
import sys
url = "http://www.gutenberg.org/files/11/11-0.txt"
title = "./alice_in_winderland.txt"
urllib.request.urlretrieve(url,"{0}".format(title))
# Out:
# ('./alice_in_winderland.txt', <http.client.HTTPMessage at 0x7f354f1ac438>)
